# %%
import pandas as pd

url = '/home/moqian/workspace/de-zoomcamp-work/01-docker-terraform/docker-workshop/pipeline/raw_data/ny_yellow_taxi_data'
des = '/home/moqian/workspace/de-zoomcamp-work/02-workflow-orchestration/ny_yellow_taxi_data'

for i in range(1, 13):
    if i <= 9:
        df = pd.read_parquet(url+f'/yellow_tripdata_2020-0{i}.parquet')
        df.to_csv(des+f'/yellow_tripdata_2020-0{i}.csv', index=False)
    else:
        df = pd.read_parquet(url+f'/yellow_tripdata_2020-{i}.parquet')
        df.to_csv(des+f'/yellow_tripdata_2020-{i}.csv', index=False)

df = pd.read_parquet(url+f'/yellow_tripdata_2021-03.parquet')
df.to_csv(des+f'/yellow_tripdata_2021-03.csv', index=False)
